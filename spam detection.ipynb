# %% [markdown]
# ### importing libraries

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\rehan\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: pillow in c:\users\rehan\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\rehan\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\rehan\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rehan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rehan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rehan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rehan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rehan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\rehan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rehan\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\rehan\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from sklearn.model_selection import train_test_split
from wordcloud import WordCloud

# %matplotlib inline

# %% [markdown]
# ### reading the csv

# %%
sms = pd.read_csv('spam.csv',encoding='ISO-8859-1')
sms.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# ###  dropping the unwanted columns and renaming the remaining columns

# %%
cols_to_drop = ['Unnamed: 2','Unnamed: 3','Unnamed: 4']
sms.drop(cols_to_drop,axis=1,inplace=True)
sms.columns = ['label','message']
sms.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
sms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    5572 non-null   object
#  1   message  5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
sms.isnull().sum()
# Out:
# label      0
# message    0
# dtype: int64

# %% [markdown]
# ### converting words into vectors and splitting data into train/test

# %%
cv = CountVectorizer(decode_error='ignore')
X = cv.fit_transform(sms['message'])

X_train, X_test, y_train, y_test = train_test_split(X, sms['label'], test_size=0.3, random_state=101)

# %%
sms['message'][0]
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...'

# %% [markdown]
# ## training the model (I also tried Tfidf Vectorizer but in this case CountVectorizer is giving better results)

# %%
mnb = MultinomialNB()
mnb.fit(X_train,y_train)
print('training accuracy is --> ',mnb.score(X_train,y_train)*100)
print('test accuracy is --> ',mnb.score(X_test,y_test)*100)
# Out:
# training accuracy is -->  99.41025641025641
# test accuracy is -->  98.56459330143541

# %%
def visualize(label):
    words = ''
    for msg in sms[sms['label']==label]['message']:
        msg = msg.lower()
        words+=msg + ' '
    wordcloud = WordCloud(width=600,height=400).generate(words)
    plt.imshow(wordcloud)
    plt.axis('off')

# %%
visualize('spam')

# %%
visualize('ham')

# %% [markdown]
# ### live predictor

# %%
# just type in your message and run
your_message = 'hi I will call you later'
your_message = cv.transform([your_message])
claass = mnb.predict(your_message)
print(f'This is a {claass[0]} message')
# Out:
# This is a ham message
